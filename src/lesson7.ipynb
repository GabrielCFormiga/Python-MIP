# %% [markdown]
# # Practical Lesson 7: TSP

# %%
from mip import *
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
def parse_atsp_file(file_content):
    """
    Parse a .tsp file with ATSP (Asymmetric Traveling Salesman Problem) format.
    Returns the dimension (number of nodes) and a matrix of edge weights.
    """
    lines = file_content.strip().splitlines()
    dimension = 0
    edge_matrix = []

    reading_matrix = False

    for line in lines:
        line = line.strip()

        if line.startswith("DIMENSION"):
            dimension = int(line.split(":")[1].strip())

        elif line.startswith("EDGE_WEIGHT_SECTION"):
            reading_matrix = True
            current_row = []

        elif reading_matrix:
            # Append numbers to the current row
            numbers = list(map(int, line.split()))
            current_row.extend(numbers)

            # When the row is complete, append it to the matrix and reset current_row
            if len(current_row) == dimension:
                edge_matrix.append(current_row)
                current_row = []

            # Stop reading when the matrix is complete
            if len(edge_matrix) == dimension:
                break

    return dimension, edge_matrix

# %%
def plot_tsp_solution(adj_matrix):
    """
    Plota um grafo direcionado dado a matriz de adjacência. O rótulo dos nó é o índice dele na matriz.

    :param adj_matrix: Matriz de adjacência do grafo direcionado, e.g., [[0, 1, 0], [0, 0, 1], [1, 0, 0]]
    """
    # Criar um grafo direcionado a partir da matriz de adjacência
    G = nx.DiGraph()

    num_nodes = len(adj_matrix)

    # Adicionar nós e arestas ao grafo
    for i in range(num_nodes):
        for j in range(num_nodes):
            if adj_matrix[i][j].x > 0:
                G.add_edge(i, j)

    # Posicionar os nós usando o layout circular
    pos = nx.circular_layout(G)

    # Criar rótulos para os nós
    labels = {i: str(i) for i in range(num_nodes)}

    # Plotar o grafo
    plt.figure(figsize=(8, 8))
    nx.draw(G, pos, with_labels=True, labels=labels,
            node_size=300, node_color='skyblue', edge_color='black', font_size=12,
            font_weight='bold', width=1.5, arrows=True, arrowstyle='-|>', arrowsize=20)

    plt.axis('off')
    plt.show()

# %%
def show_results(model):
  print(f"Objective Value: {model.objective_value}")
  print()
  for var in model.vars:
      if var.x > 0.5:  # Checar se a variável é próxima de 1 (considerando um valor binário)
          print(f"{var.name} = {var.x}")
  return

# %%
def find_cycles(adj_matrix):
    """
    Identifica subciclos em um grafo a partir de uma matriz de adjacência binária.

    :param adj_matrix: Matriz de adjacência do grafo (lista de listas).
    :return: Lista de listas contendo os nós de cada subciclo.
    """
    def dfs(v, visited, stack, path):
        visited[v] = True
        stack[v] = True
        path.append(v)

        for i in range(len(adj_matrix)):
            if adj_matrix[v][i].x == 1:
                if not visited[i]:
                    dfs(i, visited, stack, path)
                elif stack[i]:  # Um ciclo foi encontrado
                    cycle_start = path.index(i)
                    cycles.append(path[cycle_start:])

        stack[v] = False
        path.pop()

    num_nodes = len(adj_matrix)
    visited = [False] * num_nodes
    stack = [False] * num_nodes
    cycles = []

    for node in range(num_nodes):
        if not visited[node]:
            dfs(node, visited, stack, [])

    return cycles

# %% [markdown]
# # TSP Exemplo

# %% [markdown]
# O TSP (travelling salesman problem ou problema do caixeiro viajante) é um problema complexo de aplicação em muitas áreas. Iremos analisar um pequeno exemplo desse problema para podermos entender como é possível de resolver ele através da PLI.
#
# Esse problema consiste em determinar o menor ciclo (com menor custo, seja ele financeiro, distância, tempo, etc.) para se percorrer $n$ cidades diferentes. Cada cidade possui ligação com as outras, e não é possível voltar em cidades já visitadas. No fim desejamos voltar para a cidade de onde saímos no início.
#
# Abaixo se encontra a entrada em formato padrão para o nosso problema contendo 10 nós (cidades) conectados entre si. Iremos executar um dos algoritmos utilizados para resolver o TSP.

# %%
# Instância tsp a ser utilizada
file_content = """
NAME: tsp_10_nodes
TYPE: ATSP
DIMENSION: 10
EDGE_WEIGHT_TYPE: EXPLICIT
EDGE_WEIGHT_FORMAT: FULL_MATRIX
EDGE_WEIGHT_SECTION
0 10 15 20 25 30 35 40 45 50
10 0 18 22 27 33 37 43 48 55
15 18 0 25 30 35 40 45 50 55
20 22 25 0 28 32 43 48 53 58
25 27 30 28 0 33 47 52 57 62
30 33 35 32 33 0 40 48 55 60
35 37 40 43 47 40 0 38 45 52
40 43 45 48 52 48 38 0 42 49
45 48 50 53 57 55 45 42 0 50
50 55 55 58 62 60 52 49 50 0
EOF

"""

# %% [markdown]
# Podemos representar esse problema através de um grafo, e é exatamente isso o que faremos. A variável `edge_matrix` é uma matriz de adjacência contendo a ligação entre as cidades do problema e o custo (distância) para ir de uma cidade a outra.

# %%
# Parse o arquivo .tsp
dimension, edge_matrix = parse_atsp_file(file_content)
# print(f"Dimension: {dimension}")
# print(f"Edge matrix: {edge_matrix}")

# %% [markdown]
# A resolução do nosso problema é a seguinte: criamos um modelo que exigirá que todas as cidades sejam percorridas, ou seja, o ciclo final terá que passar por todas as cidades. Assim todas elas serão percorridas e a condição do problema será satisfeita.
#
# Para fazermos isso, iremos impor que, para cada cidade em nosso problema, seja necessário que exista um arco que chegue e um arco que saia dela na solução. Para isso, iremos definir uma variável binári $x_{ij}$ irá determinar se o arco que vai do nó $i$ para o nó $j$ está sendo utilizado.
#
# Logo, temos como restrições
#
# $\sum_{i} x_{ij} == 1,  ~\forall j$
#
# $\sum_{i} x_{ji} == 1,  ~\forall j$
#
# onde a primeira está dizendo que todo nó $j$ deve ter um arco que vai até ele e a segunda diz que todo nó $j$ deve ter um arco que sai dele na solução.

# %%
model = Model(sense=MINIMIZE, solver_name=CBC)

x = [[model.add_var(var_type=BINARY, name=f"x_{i}_{j}") for j in range(dimension)] for i in range(dimension)]

model.objective += (
    x[0][1] * edge_matrix[0][1] +
    x[0][2] * edge_matrix[0][2] +
    x[0][3] * edge_matrix[0][3] +
    x[0][4] * edge_matrix[0][4] +
    x[0][5] * edge_matrix[0][5] +
    x[0][6] * edge_matrix[0][6] +
    x[0][7] * edge_matrix[0][7] +
    x[0][8] * edge_matrix[0][8] +
    x[0][9] * edge_matrix[0][9] +

    x[1][0] * edge_matrix[1][0] +
    x[1][2] * edge_matrix[1][2] +
    x[1][3] * edge_matrix[1][3] +
    x[1][4] * edge_matrix[1][4] +
    x[1][5] * edge_matrix[1][5] +
    x[1][6] * edge_matrix[1][6] +
    x[1][7] * edge_matrix[1][7] +
    x[1][8] * edge_matrix[1][8] +
    x[1][9] * edge_matrix[1][9] +

    x[2][0] * edge_matrix[2][0] +
    x[2][1] * edge_matrix[2][1] +
    x[2][3] * edge_matrix[2][3] +
    x[2][4] * edge_matrix[2][4] +
    x[2][5] * edge_matrix[2][5] +
    x[2][6] * edge_matrix[2][6] +
    x[2][7] * edge_matrix[2][7] +
    x[2][8] * edge_matrix[2][8] +
    x[2][9] * edge_matrix[2][9] +

    x[3][0] * edge_matrix[3][0] +
    x[3][1] * edge_matrix[3][1] +
    x[3][2] * edge_matrix[3][2] +
    x[3][4] * edge_matrix[3][4] +
    x[3][5] * edge_matrix[3][5] +
    x[3][6] * edge_matrix[3][6] +
    x[3][7] * edge_matrix[3][7] +
    x[3][8] * edge_matrix[3][8] +
    x[3][9] * edge_matrix[3][9] +

    x[4][0] * edge_matrix[4][0] +
    x[4][1] * edge_matrix[4][1] +
    x[4][2] * edge_matrix[4][2] +
    x[4][3] * edge_matrix[4][3] +
    x[4][5] * edge_matrix[4][5] +
    x[4][6] * edge_matrix[4][6] +
    x[4][7] * edge_matrix[4][7] +
    x[4][8] * edge_matrix[4][8] +
    x[4][9] * edge_matrix[4][9] +

    x[5][0] * edge_matrix[5][0] +
    x[5][1] * edge_matrix[5][1] +
    x[5][2] * edge_matrix[5][2] +
    x[5][3] * edge_matrix[5][3] +
    x[5][4] * edge_matrix[5][4] +
    x[5][6] * edge_matrix[5][6] +
    x[5][7] * edge_matrix[5][7] +
    x[5][8] * edge_matrix[5][8] +
    x[5][9] * edge_matrix[5][9] +

    x[6][0] * edge_matrix[6][0] +
    x[6][1] * edge_matrix[6][1] +
    x[6][2] * edge_matrix[6][2] +
    x[6][3] * edge_matrix[6][3] +
    x[6][4] * edge_matrix[6][4] +
    x[6][5] * edge_matrix[6][5] +
    x[6][7] * edge_matrix[6][7] +
    x[6][8] * edge_matrix[6][8] +
    x[6][9] * edge_matrix[6][9] +

    x[7][0] * edge_matrix[7][0] +
    x[7][1] * edge_matrix[7][1] +
    x[7][2] * edge_matrix[7][2] +
    x[7][3] * edge_matrix[7][3] +
    x[7][4] * edge_matrix[7][4] +
    x[7][5] * edge_matrix[7][5] +
    x[7][6] * edge_matrix[7][6] +
    x[7][8] * edge_matrix[7][8] +
    x[7][9] * edge_matrix[7][9] +

    x[8][0] * edge_matrix[8][0] +
    x[8][1] * edge_matrix[8][1] +
    x[8][2] * edge_matrix[8][2] +
    x[8][3] * edge_matrix[8][3] +
    x[8][4] * edge_matrix[8][4] +
    x[8][5] * edge_matrix[8][5] +
    x[8][6] * edge_matrix[8][6] +
    x[8][7] * edge_matrix[8][7] +
    x[8][9] * edge_matrix[8][9] +

    x[9][0] * edge_matrix[9][0] +
    x[9][1] * edge_matrix[9][1] +
    x[9][2] * edge_matrix[9][2] +
    x[9][3] * edge_matrix[9][3] +
    x[9][4] * edge_matrix[9][4] +
    x[9][5] * edge_matrix[9][5] +
    x[9][6] * edge_matrix[9][6] +
    x[9][7] * edge_matrix[9][7] +
    x[9][8] * edge_matrix[9][8]
)


model += x[0][1] + x[0][2] + x[0][3] + x[0][4] + x[0][5] + x[0][6] + x[0][7] + x[0][8] + x[0][9] == 1
model += x[1][0] + x[1][2] + x[1][3] + x[1][4] + x[1][5] + x[1][6] + x[1][7] + x[1][8] + x[1][9] == 1
model += x[2][0] + x[2][1] + x[2][3] + x[2][4] + x[2][5] + x[2][6] + x[2][7] + x[2][8] + x[2][9] == 1
model += x[3][0] + x[3][1] + x[3][2] + x[3][4] + x[3][5] + x[3][6] + x[3][7] + x[3][8] + x[3][9] == 1
model += x[4][0] + x[4][1] + x[4][2] + x[4][3] + x[4][5] + x[4][6] + x[4][7] + x[4][8] + x[4][9] == 1
model += x[5][0] + x[5][1] + x[5][2] + x[5][3] + x[5][4] + x[5][6] + x[5][7] + x[5][8] + x[5][9] == 1
model += x[6][0] + x[6][1] + x[6][2] + x[6][3] + x[6][4] + x[6][5] + x[6][7] + x[6][8] + x[6][9] == 1
model += x[7][0] + x[7][1] + x[7][2] + x[7][3] + x[7][4] + x[7][5] + x[7][6] + x[7][8] + x[7][9] == 1
model += x[8][0] + x[8][1] + x[8][2] + x[8][3] + x[8][4] + x[8][5] + x[8][6] + x[8][7] + x[8][9] == 1
model += x[9][0] + x[9][1] + x[9][2] + x[9][3] + x[9][4] + x[9][5] + x[9][6] + x[9][7] + x[9][8] == 1

model += x[1][0] + x[2][0] + x[3][0] + x[4][0] + x[5][0] + x[6][0] + x[7][0] + x[8][0] + x[9][0] == 1
model += x[0][1] + x[2][1] + x[3][1] + x[4][1] + x[5][1] + x[6][1] + x[7][1] + x[8][1] + x[9][1] == 1
model += x[0][2] + x[1][2] + x[3][2] + x[4][2] + x[5][3] + x[6][2] + x[7][2] + x[8][2] + x[9][2] == 1
model += x[0][3] + x[1][3] + x[2][3] + x[4][3] + x[5][3] + x[6][3] + x[7][3] + x[8][3] + x[9][3] == 1
model += x[0][4] + x[1][4] + x[2][4] + x[3][4] + x[5][4] + x[6][4] + x[7][4] + x[8][4] + x[9][4] == 1
model += x[0][5] + x[1][5] + x[2][5] + x[3][5] + x[4][5] + x[6][5] + x[7][5] + x[8][5] + x[9][5] == 1
model += x[0][6] + x[1][6] + x[2][6] + x[3][6] + x[4][6] + x[5][6] + x[7][6] + x[8][6] + x[9][6] == 1
model += x[0][7] + x[1][7] + x[2][7] + x[3][7] + x[4][7] + x[5][7] + x[6][7] + x[8][7] + x[9][7] == 1
model += x[0][8] + x[1][8] + x[2][8] + x[3][8] + x[4][8] + x[5][8] + x[6][8] + x[7][8] + x[9][8] == 1
model += x[0][9] + x[1][9] + x[2][9] + x[3][9] + x[4][9] + x[5][9] + x[6][9] + x[7][9] + x[8][9] == 1


model.optimize()
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 20 (0) rows, 90 (-10) columns and 180 (0) elements
# Clp1000I sum of infeasibilities 4.84251e-07 - average 2.42126e-08, 28 fixed columns
# Coin0506I Presolve 20 (0) rows, 62 (-28) columns and 124 (-56) elements
# Clp0006I 0  Obj 312.00167 Dual inf 206400 (61)
# Clp0029I End of values pass after 61 iterations
# Clp0014I Perturbing problem by 0.001% of 1.0000016 - largest nonzero change 2.6625829e-05 ( 0.0013312914%) - largest zero change 2.9031261e-05
# Clp0000I Optimal - objective value 312
# Clp0000I Optimal - objective value 312
# Coin0511I After Postsolve, objective 312, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 312
# Clp0000I Optimal - objective value 312
# Clp0000I Optimal - objective value 312
# Clp0000I Optimal - objective value 312
# Coin0511I After Postsolve, objective 312, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 312 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 20 rows, 90 columns (90 integer (90 of which binary)) and 180 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 4.972%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 0.00011
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 312
# Cbc0038I Before mini branch and bound, 90 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 312 - took 0.00 seconds
# Cbc0012I Integer solution of 312 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 312, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# <OptimizationStatus.OPTIMAL: 0>

# %% [markdown]
# No entanto, nem tudo são flores. Em nenhum momento as restrições acima obrigam que a solução seja um único ciclo no grafo. Ou seja, as restrições não obrigam que no ciclo gerado seja possível sair de um nó e chegar em qualquer outro nó do grafo. Por conta disso, a chance de que subciclos no grafo sejam gerados é alta. Por isso, iremos para a segunda parte do algoritmo para resolver o TSP.
#
# Nessa parte, devemos avaliar a resposta do resolvedor e analisar se ela contém um único ciclo. No nosso caso, possuímos 5 subciclos diferentes em nossa resposta. Podemos ver isso abaixo no grafo que representa a solução encontrada.

# %%
plot_tsp_solution(x)

# %% [markdown]
# Para resolvermos esse problema, precisamos proibir que esses subciclos possam ser gerado pelo resolvedor. Para  isso, denotamos por $S$ o conjunto que contém os nós do subciclo. Iremos adicionar a seguinte restrição:
#
# $\sum_{i ~\in~ S}\sum_{j~ \in~ S : ~j ~\not= ~i} x_{ij} <= |S| - 1$.
#
# A restrição força que, dentre todos os arcos possíveis entre vértices do conjunto $S$, no máximo $|S|-1$ estejam presentes na solução. Isso impede que seja formado qualquer subciclo com os vértices de $S$ (em qualquer ordem, e não apenas na ordem que apareceu na solução).
#
# Dessa forma, iremos adicionar essas restrições ao modelo.

# %%
model += x[4][5] + x[5][4] <= 1
model += x[3][2] + x[2][3] <= 1
model += x[6][7] + x[7][6] <= 1
model += x[9][8] + x[8][9] <= 1
model += x[0][1] + x[1][0] <= 1

model.optimize()

plot_tsp_solution(x)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0006I 0  Obj 312 Primal inf 4.999995 (5) Dual inf 1.29e+12 (39)
# Clp0014I Perturbing problem by 0.001% of 1.000001 - largest nonzero change 2.3041111e-05 ( 0.0011520555%) - largest zero change 2.3044642e-05
# Clp0000I Optimal - objective value 318
#
# Starting MIP optimization
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 25 rows, 90 columns (90 integer (90 of which binary)) and 191 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 5.003%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Fixing only non-zero variables.
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0045I Nauty did not find any useful orbits in time 0.000163
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 318
# Cbc0038I Before mini branch and bound, 90 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 318 - took 0.00 seconds
# Cbc0012I Integer solution of 318 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 318, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %% [markdown]
# Infelizmente ainda não obtivemos uma resposta da forma como desejávamos. No entanto, aqueles subciclos da última resolução não foram repetidos.

# %%
model += x[3][4] + x[3][5] + x[4][3] + x[4][5] + x[5][4] + x[5][3]  <= 2
model += x[1][0] + x[1][2] + x[0][1] + x[0][2] + x[2][0] + x[2][1]  <= 2
model += x[6][7] + x[6][8] + x[6][9] + x[7][6] + x[7][8] + x[7][9] + x[9][6] + x[9][7] + x[9][8] + x[8][6] + x[8][7] + x[8][9]  <= 3

model.optimize()
print("Solution value  = ", model.objective_value)
plot_tsp_solution(x)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0006I 0  Obj 318 Primal inf 2.999997 (3) Dual inf 5.4e+11 (39)
# Clp0014I Perturbing problem by 0.001% of 1.037038 - largest nonzero change 2.4463547e-05 ( 0.0012231774%) - largest zero change 2.0623556e-05
# Clp0000I Optimal - objective value 326
#
# Starting MIP optimization
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 28 rows, 90 columns (90 integer (90 of which binary)) and 215 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 5.003%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Fixing only non-zero variables.
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0045I Nauty did not find any useful orbits in time 0.000109
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 326
# Cbc0038I Before mini branch and bound, 90 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 326 - took 0.00 seconds
# Cbc0012I Integer solution of 326 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 326, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solution value  =  326.0

# %%
model += x[0][1] + x[0][2] + x[0][3] + x[0][4] + x[1][0] + x[1][2] + x[1][3] + x[1][4] + x[2][0] + x[2][1] + x[2][3] + x[2][4] + x[3][0] + x[3][1] + x[3][2] + x[3][4] + x[4][0] + x[4][1] + x[4][2] + x[4][3] <= 4
model += x[7][8] + x[7][9] + x[8][7] + x[8][9] + x[9][7] + x[9][8] <= 2
model += x[5][6] + x[6][5] <= 1

model.optimize()
print("Solution value  = ", model.objective_value)
plot_tsp_solution(x)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0006I 0  Obj 326 Primal inf 2.999997 (3) Dual inf 1.22e+12 (46)
# Clp0014I Perturbing problem by 0.001% of 1.072073 - largest nonzero change 2.4018744e-05 ( 0.0012009372%) - largest zero change 2.3044642e-05
# Clp0000I Optimal - objective value 333
#
# Starting MIP optimization
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 31 rows, 90 columns (90 integer (90 of which binary)) and 243 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 5.009%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Fixing only non-zero variables.
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0045I Nauty did not find any useful orbits in time 0.000116
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 333
# Cbc0038I Before mini branch and bound, 90 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of 333 - took 0.00 seconds
# Cbc0012I Integer solution of 333 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 333, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solution value  =  333.0

# %% [markdown]
# Através desse algoritmo, é possível calcular a solução ótima para o TSP. No entanto, seria impraticável visualizar a solução a cada iteração do algoritmo e então proibir os subciclos contidos nela. Por isso, a execução acima do algoritmo foi feita apenas com fins didáticos. Na realidade, esse algoritmo possui um loop *while* que se encarrega de gerenciar todas as iterações.

# %% [markdown]
# ## Prática
# Agora é com você. Resolva o mesmo problema para as instâncias abaixo fazendo a segunda parte do algoritmo dentro do loop *while*. Você pode utilizar qualquer das funções contidas na aba **Funções** para auxiliá-lo.

# %% [markdown]
# **Primeira Instância**
#
# Arquivo: https://www.dropbox.com/scl/fi/lude86d562bapdebn1kah/ft70.atsp?rlkey=fdyoz5mefuf8mwc652or9010p&dl=0
#
# Valor Ótimo: 38673.0
#
# -------------------------------------------------------------------------
#
# **Segunda Instância**
#
# Arquivo: https://www.dropbox.com/scl/fi/748iyf5zubmr08ch3cuyk/kro124p.atsp?rlkey=df91hsx9uyk90u8nyl2cgc174&dl=0
#
# Valor Ótimo: 36230.0

# %%
# Instância tsp a ser utilizada
# with open('../data/tsp_instances/ft70.atsp', 'r') as arquivo:
with open('../data/tsp_instances/kro124p.atsp', 'r') as arquivo:
    file_content = arquivo.read()

# %%
# Parse do arquivo .tsp
dimension, edge_matrix = parse_atsp_file(file_content)
# print(f"Dimension: {dimension}")
# print(f"Edge matrix: {edge_matrix}")

# %% [markdown]
# Primeira parte: definição inicial do modelo.
#
# ---

# %%
model = Model(sense=MINIMIZE, solver_name=CBC)

x = [[model.add_var(var_type=BINARY, name=f"x_{i}_{j}") for j in range(dimension)] for i in range(dimension)]

# Função objetivo
model.objective += xsum(edge_matrix[i][j] * x[i][j] for i in range(dimension) for j in range(dimension) if i != j)

# Restrições iniciais do modelo
for i in range(dimension):
    model += xsum(x[i][j] for j in range(dimension) if i != j) == 1

for j in range(dimension):
    model += xsum(x[i][j] for i in range(dimension) if i != j) == 1

model.optimize()
print("Solution value  = ", model.objective_value)
plot_tsp_solution(x)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 200 (0) rows, 9900 (-100) columns and 19800 (0) elements
# Clp1000I sum of infeasibilities 5.97837e-05 - average 2.98918e-07, 9767 fixed columns
# Coin0506I Presolve 1 (-199) rows, 3 (-9897) columns and 3 (-19797) elements
# Clp0006I 0  Obj 33978.005 Primal inf 3.9731412e-06 (1) Dual inf 3.0000002e+12 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 33978
# Clp0000I Optimal - objective value 33978
# Coin0511I After Postsolve, objective 33978, infeasibilities - dual 198 (1), primal 0 (0)
# Coin0512I Presolved model was optimal, full model needs cleaning up
# Clp0006I 0  Obj 33978 Dual inf 32787 (175)
# Clp0014I Perturbing problem by 0.001% of 1 - largest nonzero change 2.9522154e-05 ( 0.0014761077%) - largest zero change 2.9576128e-05
# Clp0000I Optimal - objective value 33978
# Clp0000I Optimal - objective value 33978
# Clp0000I Optimal - objective value 33978
# Coin0511I After Postsolve, objective 33978, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 33978 - 0 iterations time 0.052, Presolve 0.00, Idiot 0.04
#
# Starting MIP optimization
# Cgl0004I processed model has 200 rows, 9900 columns (9900 integer (9900 of which binary)) and 19800 elements
# Coin3009W Conflict graph built in 0.047 seconds, density: 0.500%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 0.109458
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 33978
# Cbc0038I Before mini branch and bound, 9900 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.28 seconds)
# Cbc0038I After 0.28 seconds - Feasibility pump exiting with objective of 33978 - took 0.01 seconds
# Cbc0012I Integer solution of 33978 found by feasibility pump after 0 iterations and 0 nodes (0.28 seconds)
# Cbc0001I Search completed - best objective 33978, took 0 iterations and 0 nodes (0.29 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.27   (Wallclock seconds):       0.30
#
# Solution value  =  33978.0

# %% [markdown]
# Segunda parte: atualização do modelo para garantir que exista apenas um ciclo
#
# *   Item da lista
# *   Item da lista
#
# no grafo contendo a solução.

# %%
while True:
  # Verificação de subciclos na resolução
  cycles = find_cycles(x)

  if (len(cycles) == 1):
    break

  # Proibição dos subciclos caso existam
  for cycle in cycles:
    model += xsum(x[i][j] for i in cycle for j in cycle if i != j) <= len(cycle) - 1

  model.optimize()

print("Solution value  = ", model.objective_value)
# plot_tsp_solution(x)
# Out:
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0006I 0  Obj 33978 Primal inf 31.999968 (32) Dual inf 2.1702999e+14 (5228)
# Clp0014I Perturbing problem by 0.001% of 1.0035885 - largest nonzero change 2.9274039e-05 ( 0.001463702%) - largest zero change 2.9950208e-05
# Clp0000I Optimal - objective value 35393
#
# Starting MIP optimization
# Cgl0004I processed model has 232 rows, 9900 columns (9900 integer (9900 of which binary)) and 20074 elements
# Coin3009W Conflict graph built in 0.050 seconds, density: 0.500%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Fixing only non-zero variables.
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0045I Nauty did not find any useful orbits in time 0.112252
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of 35393
# Cbc0038I Before mini branch and bound, 9900 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.31 seconds)
# Cbc0038I After 0.31 seconds - Feasibility pump exiting with objective of 35393 - took 0.01 seconds
# Cbc0012I Integer solution of 35393 found by feasibility pump after 0 iterations and 0 nodes (0.31 seconds)
# Cbc0001I Search completed - best objective 35393, took 0 iterations and 0 nodes (0.32 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.30   (Wallclock seconds):       0.32
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0006I 0  Obj 35393 Primal inf 18.999981 (19) Dual inf 4.6965999e+14 (4779)
# Clp0014I Perturbing problem by 0.001% of 1.0097503 - largest nonzero change 2.9950208e-05 ( 0.0014975104%) - largest zero change 2.9274039e-05
# Clp0000I Optimal - objective value 35798.417
#
# Starting MIP optimization
# Cgl0004I processed model has 251 rows, 9900 columns (9900 integer (9900 of which binary)) and 21368 elements
# Coin3009W Conflict graph built in 0.048 seconds, density: 0.500%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Fixing only non-zero variables.
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0045I Nauty did not find any useful orbits in time 0.111549
# Cbc0038I Initial state - 139 integers unsatisfied sum - 49.6667
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 75263 iterations 503
# Cbc0038I Solution found of 75263
# Cbc0038I Before mini branch and bound, 9731 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 251 rows 9900 columns, reduced to 89 rows 100 columns
# Cbc0038I Mini branch and bound improved solution from 75263 to 37269 (0.39 seconds)
# Cbc0038I Round again with cutoff of 37121
# Cbc0038I Reduced cost fixing fixed 5172 variables on major pass 2
# Cbc0038I Pass   2: suminf.   22.01054 (53) obj. 37121 iterations 612
# Cbc0038I Pass   3: suminf.    1.52112 (4) obj. 37121 iterations 151
# Cbc0038I Solution found of 36929
# Cbc0038I Before mini branch and bound, 9738 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 251 rows 9900 columns, reduced to 52 rows 55 columns
# Cbc0038I Mini branch and bound improved solution from 36929 to 36108 (0.47 seconds)
# Cbc0038I Round again with cutoff of 36045.3
# Cbc0038I Reduced cost fixing fixed 9183 variables on major pass 3
# Cbc0038I Pass   4: suminf.    8.99547 (40) obj. 36045.3 iterations 108
# Cbc0038I Pass   5: suminf.    0.88284 (8) obj. 36045.3 iterations 208
# Cbc0038I Solution found of 36038
# Cbc0038I Before mini branch and bound, 9749 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 251 rows 9900 columns, reduced to 40 rows 37 columns
# Cbc0038I Mini branch and bound improved solution from 36038 to 36004 (0.54 seconds)
# Cbc0038I Round again with cutoff of 35941.6
# Cbc0038I Reduced cost fixing fixed 9432 variables on major pass 4
# Cbc0038I Pass   6: suminf.   15.75106 (109) obj. 35941.6 iterations 66
# Cbc0038I Pass   7: suminf.   10.46656 (26) obj. 35941.6 iterations 22
# Cbc0038I Pass   8: suminf.   10.46656 (26) obj. 35941.6 iterations 1
# Cbc0038I Pass   9: suminf.    9.21153 (27) obj. 35941.6 iterations 11
# Cbc0038I Pass  10: suminf.    9.21153 (27) obj. 35941.6 iterations 6
# Cbc0038I Pass  11: suminf.    9.21153 (27) obj. 35941.6 iterations 2
# Cbc0038I Pass  12: suminf.    9.21153 (27) obj. 35941.6 iterations 0
# Cbc0038I Pass  13: suminf.    8.77188 (20) obj. 35941.6 iterations 48
# Cbc0038I Pass  14: suminf.    5.96665 (12) obj. 35941.6 iterations 79
# Cbc0038I Pass  15: suminf.    4.71370 (14) obj. 35941.6 iterations 63
# Cbc0038I Pass  16: suminf.    4.71370 (14) obj. 35941.6 iterations 0
# Cbc0038I Pass  17: suminf.    5.07703 (14) obj. 35941.6 iterations 64
# Cbc0038I Pass  18: suminf.    5.07703 (14) obj. 35941.6 iterations 33
# Cbc0038I Pass  19: suminf.    4.71370 (14) obj. 35941.6 iterations 22
# Cbc0038I Pass  20: suminf.    4.71370 (14) obj. 35941.6 iterations 11
# Cbc0038I Pass  21: suminf.    4.71370 (14) obj. 35941.6 iterations 14
# Cbc0038I Pass  22: suminf.    4.71370 (14) obj. 35941.6 iterations 0
# Cbc0038I Pass  23: suminf.    5.07703 (14) obj. 35941.6 iterations 45
# Cbc0038I Pass  24: suminf.    5.07703 (14) obj. 35941.6 iterations 36
# Cbc0038I Pass  25: suminf.    4.71370 (14) obj. 35941.6 iterations 28
# Cbc0038I Pass  26: suminf.    4.71370 (14) obj. 35941.6 iterations 9
# Cbc0038I Pass  27: suminf.    4.71370 (14) obj. 35941.6 iterations 2
# Cbc0038I Pass  28: suminf.    4.71370 (14) obj. 35941.6 iterations 3
# Cbc0038I Pass  29: suminf.    4.71370 (14) obj. 35941.6 iterations 3
# Cbc0038I Pass  30: suminf.    4.71370 (14) obj. 35941.6 iterations 25
# Cbc0038I Pass  31: suminf.    4.71370 (14) obj. 35941.6 iterations 33
# Cbc0038I Pass  32: suminf.    4.71370 (14) obj. 35941.6 iterations 0
# Cbc0038I Pass  33: suminf.    5.07703 (14) obj. 35941.6 iterations 19
# Cbc0038I Pass  34: suminf.    5.07703 (14) obj. 35941.6 iterations 12
# Cbc0038I Pass  35: suminf.    4.71370 (14) obj. 35941.6 iterations 19
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9748 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 251 rows 9900 columns, reduced to 46 rows 43 columns
# Cbc0038I Mini branch and bound did not improve solution (0.68 seconds)
# Cbc0038I After 0.68 seconds - Feasibility pump exiting with objective of 36004 - took 0.22 seconds
# Cbc0012I Integer solution of 36004 found by feasibility pump after 0 iterations and 0 nodes (0.68 seconds)
# Cbc0038I Full problem 251 rows 9900 columns, reduced to 158 rows 312 columns
# Cbc0012I Integer solution of 35964 found by greedy equality after 0 iterations and 0 nodes (0.77 seconds)
# Cbc0038I Full problem 251 rows 9900 columns, reduced to 32 rows 23 columns
# Cbc0012I Integer solution of 35940 found by DiveCoefficient after 29 iterations and 0 nodes (0.86 seconds)
# Cbc0031I 9 added rows had average density of 6.1111111
# Cbc0013I At root node, 9 cuts changed objective from 35798.417 to 35940 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 18 row cuts average 2.3 elements, 45 column cuts (45 active)  in 0.005 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 14.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 7 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 8 row cuts average 6.4 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 35940, took 29 iterations and 0 nodes (0.87 seconds)
# Cbc0035I Maximum depth 0, 9582 variables fixed on reduced cost
# Total time (CPU seconds):       0.64   (Wallclock seconds):       0.88
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0006I 0  Obj 35798.417 Primal inf 3.249993 (7) Dual inf 1.1684249e+14 (4586)
# Clp0014I Perturbing problem by 0.001% of 1.0170906 - largest nonzero change 2.9274039e-05 ( 0.001463702%) - largest zero change 2.9950208e-05
# Clp0000I Optimal - objective value 35910.167
#
# Starting MIP optimization
# Cgl0004I processed model has 264 rows, 9900 columns (9900 integer (9900 of which binary)) and 23118 elements
# Coin3009W Conflict graph built in 0.049 seconds, density: 0.500%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Fixing only non-zero variables.
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0045I Nauty did not find any useful orbits in time 0.114241
# Cbc0038I Initial state - 88 integers unsatisfied sum - 31
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 58034 iterations 465
# Cbc0038I Solution found of 58034
# Cbc0038I Before mini branch and bound, 9795 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 264 rows 9900 columns, reduced to 62 rows 62 columns
# Cbc0038I Mini branch and bound improved solution from 58034 to 36322 (0.41 seconds)
# Cbc0038I Round again with cutoff of 36279.9
# Cbc0038I Reduced cost fixing fixed 8812 variables on major pass 2
# Cbc0038I Pass   2: suminf.    7.34108 (19) obj. 36279.9 iterations 288
# Cbc0038I Pass   3: suminf.    7.34108 (19) obj. 36279.9 iterations 88
# Cbc0038I Pass   4: suminf.    7.34108 (19) obj. 36279.9 iterations 3
# Cbc0038I Pass   5: suminf.    7.34108 (19) obj. 36279.9 iterations 3
# Cbc0038I Pass   6: suminf.    7.34108 (19) obj. 36279.9 iterations 1
# Cbc0038I Pass   7: suminf.    7.34108 (19) obj. 36279.9 iterations 3
# Cbc0038I Pass   8: suminf.    4.81863 (14) obj. 36279.9 iterations 19
# Cbc0038I Pass   9: suminf.    3.82309 (9) obj. 36279.9 iterations 36
# Cbc0038I Pass  10: suminf.    3.61697 (9) obj. 36279.9 iterations 63
# Cbc0038I Pass  11: suminf.    3.61697 (9) obj. 36279.9 iterations 47
# Cbc0038I Pass  12: suminf.    3.82309 (9) obj. 36279.9 iterations 80
# Cbc0038I Pass  13: suminf.    3.61697 (9) obj. 36279.9 iterations 120
# Cbc0038I Pass  14: suminf.    3.82309 (9) obj. 36279.9 iterations 87
# Cbc0038I Pass  15: suminf.    3.61697 (9) obj. 36279.9 iterations 145
# Cbc0038I Pass  16: suminf.    3.79151 (8) obj. 36279.9 iterations 105
# Cbc0038I Pass  17: suminf.    3.79151 (8) obj. 36279.9 iterations 62
# Cbc0038I Pass  18: suminf.    3.61697 (9) obj. 36279.9 iterations 128
# Cbc0038I Pass  19: suminf.    4.00000 (8) obj. 36266 iterations 103
# Cbc0038I Pass  20: suminf.    3.82309 (9) obj. 36279.9 iterations 120
# Cbc0038I Pass  21: suminf.    3.82309 (9) obj. 36279.9 iterations 33
# Cbc0038I Pass  22: suminf.    3.61697 (9) obj. 36279.9 iterations 65
# Cbc0038I Pass  23: suminf.    3.61697 (9) obj. 36279.9 iterations 57
# Cbc0038I Pass  24: suminf.    3.82309 (9) obj. 36279.9 iterations 84
# Cbc0038I Pass  25: suminf.    3.61697 (9) obj. 36279.9 iterations 73
# Cbc0038I Pass  26: suminf.    3.81361 (9) obj. 36279.9 iterations 86
# Cbc0038I Pass  27: suminf.    3.81361 (9) obj. 36279.9 iterations 58
# Cbc0038I Pass  28: suminf.    3.79634 (9) obj. 36279.9 iterations 56
# Cbc0038I Pass  29: suminf.    3.79634 (9) obj. 36279.9 iterations 35
# Cbc0038I Pass  30: suminf.    3.81361 (9) obj. 36279.9 iterations 54
# Cbc0038I Pass  31: suminf.    3.61697 (9) obj. 36279.9 iterations 143
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9806 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 264 rows 9900 columns, reduced to 37 rows 32 columns
# Cbc0038I Mini branch and bound improved solution from 36322 to 36196 (0.58 seconds)
# Cbc0038I Round again with cutoff of 36138
# Cbc0038I Reduced cost fixing fixed 9200 variables on major pass 3
# Cbc0038I Pass  31: suminf.   18.45396 (60) obj. 36138 iterations 123
# Cbc0038I Pass  32: suminf.   18.09860 (78) obj. 36138 iterations 31
# Cbc0038I Pass  33: suminf.   18.09860 (78) obj. 36138 iterations 7
# Cbc0038I Pass  34: suminf.   13.52574 (68) obj. 36138 iterations 8
# Cbc0038I Pass  35: suminf.   11.21613 (58) obj. 36138 iterations 7
# Cbc0038I Pass  36: suminf.   10.99400 (57) obj. 36138 iterations 9
# Cbc0038I Pass  37: suminf.   10.99400 (57) obj. 36138 iterations 8
# Cbc0038I Pass  38: suminf.   10.99400 (57) obj. 36138 iterations 3
# Cbc0038I Pass  39: suminf.   11.00599 (57) obj. 36138 iterations 18
# Cbc0038I Pass  40: suminf.   11.01176 (59) obj. 36138 iterations 18
# Cbc0038I Pass  41: suminf.   10.99400 (57) obj. 36138 iterations 15
# Cbc0038I Pass  42: suminf.   11.11530 (57) obj. 36138 iterations 23
# Cbc0038I Pass  43: suminf.   11.01176 (59) obj. 36138 iterations 17
# Cbc0038I Pass  44: suminf.   10.99400 (57) obj. 36138 iterations 9
# Cbc0038I Pass  45: suminf.   10.99400 (57) obj. 36138 iterations 1
# Cbc0038I Pass  46: suminf.   11.01176 (59) obj. 36138 iterations 19
# Cbc0038I Pass  47: suminf.   10.99400 (57) obj. 36138 iterations 13
# Cbc0038I Pass  48: suminf.   11.01176 (59) obj. 36138 iterations 17
# Cbc0038I Pass  49: suminf.   10.99400 (57) obj. 36138 iterations 16
# Cbc0038I Pass  50: suminf.   11.01176 (59) obj. 36138 iterations 11
# Cbc0038I Pass  51: suminf.   10.99400 (57) obj. 36138 iterations 14
# Cbc0038I Pass  52: suminf.   11.03016 (55) obj. 36138 iterations 13
# Cbc0038I Pass  53: suminf.   10.99400 (57) obj. 36138 iterations 15
# Cbc0038I Pass  54: suminf.   10.99400 (57) obj. 36138 iterations 0
# Cbc0038I Pass  55: suminf.   11.00599 (57) obj. 36138 iterations 13
# Cbc0038I Pass  56: suminf.   11.44192 (38) obj. 36138 iterations 19
# Cbc0038I Pass  57: suminf.   10.99400 (57) obj. 36138 iterations 26
# Cbc0038I Pass  58: suminf.   10.99400 (57) obj. 36138 iterations 9
# Cbc0038I Pass  59: suminf.   11.02982 (41) obj. 36138 iterations 21
# Cbc0038I Pass  60: suminf.   10.99400 (57) obj. 36138 iterations 27
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9802 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.68 seconds)
# Cbc0038I After 0.68 seconds - Feasibility pump exiting with objective of 36196 - took 0.29 seconds
# Cbc0012I Integer solution of 36196 found by feasibility pump after 0 iterations and 0 nodes (0.68 seconds)
# Cbc0038I Full problem 264 rows 9900 columns, reduced to 107 rows 234 columns
# Cbc0012I Integer solution of 36139 found by greedy equality after 0 iterations and 0 nodes (0.75 seconds)
# Cbc0038I Full problem 264 rows 9900 columns, reduced to 28 rows 21 columns
# Cbc0031I 16 added rows had average density of 17.8125
# Cbc0013I At root node, 16 cuts changed objective from 35910.167 to 36126.667 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 28 row cuts average 2.0 elements, 55 column cuts (55 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 13 row cuts average 98.2 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 17 row cuts average 6.2 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 36139, took 60 iterations and 0 nodes (0.84 seconds)
# Cbc0032I Strong branching done 4 times (23 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 9581 variables fixed on reduced cost
# Total time (CPU seconds):       0.69   (Wallclock seconds):       0.85
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0006I 0  Obj 35910.167 Primal inf 1.3333293 (4) Dual inf 1.3682999e+14 (4105)
# Clp0014I Perturbing problem by 0.001% of 1.0260205 - largest nonzero change 2.9274039e-05 ( 0.001463702%) - largest zero change 2.9598483e-05
# Clp0000I Optimal - objective value 35932.167
#
# Starting MIP optimization
# Cgl0004I processed model has 269 rows, 9900 columns (9900 integer (9900 of which binary)) and 27552 elements
# Coin3009W Conflict graph built in 0.050 seconds, density: 0.500%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Fixing only non-zero variables.
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0045I Nauty did not find any useful orbits in time 0.111641
# Cbc0038I Initial state - 79 integers unsatisfied sum - 29.3333
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 56579 iterations 486
# Cbc0038I Solution found of 56579
# Cbc0038I Before mini branch and bound, 9808 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 269 rows 9900 columns, reduced to 50 rows 43 columns
# Cbc0038I Mini branch and bound improved solution from 56579 to 45553 (0.45 seconds)
# Cbc0038I Round again with cutoff of 44590
# Cbc0038I Pass   2: suminf.    1.34101 (10) obj. 44590 iterations 175
# Cbc0038I Solution found of 44098
# Cbc0038I Before mini branch and bound, 9805 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 269 rows 9900 columns, reduced to 45 rows 39 columns
# Cbc0038I Mini branch and bound improved solution from 44098 to 38729 (0.53 seconds)
# Cbc0038I Round again with cutoff of 38168.8
# Cbc0038I Reduced cost fixing fixed 2204 variables on major pass 3
# Cbc0038I Pass   3: suminf.    3.89723 (11) obj. 38168.8 iterations 204
# Cbc0038I Pass   4: suminf.    0.80757 (4) obj. 38168.8 iterations 182
# Cbc0038I Pass   5: suminf.    0.80757 (4) obj. 38168.8 iterations 33
# Cbc0038I Solution found of 37255
# Cbc0038I Before mini branch and bound, 9806 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 269 rows 9900 columns, reduced to 41 rows 34 columns
# Cbc0038I Mini branch and bound improved solution from 37255 to 36455 (0.62 seconds)
# Cbc0038I Round again with cutoff of 36297.5
# Cbc0038I Reduced cost fixing fixed 8820 variables on major pass 4
# Cbc0038I Pass   6: suminf.    9.75745 (33) obj. 36297.5 iterations 227
# Cbc0038I Pass   7: suminf.    9.75745 (33) obj. 36297.5 iterations 41
# Cbc0038I Pass   8: suminf.    5.05464 (23) obj. 36297.5 iterations 7
# Cbc0038I Pass   9: suminf.    5.05464 (23) obj. 36297.5 iterations 7
# Cbc0038I Pass  10: suminf.    6.65992 (16) obj. 36297.5 iterations 59
# Cbc0038I Pass  11: suminf.    6.64994 (20) obj. 36297.5 iterations 16
# Cbc0038I Pass  12: suminf.    4.02619 (16) obj. 36297.5 iterations 53
# Cbc0038I Pass  13: suminf.    4.02619 (16) obj. 36297.5 iterations 4
# Cbc0038I Pass  14: suminf.    4.02619 (16) obj. 36297.5 iterations 4
# Cbc0038I Pass  15: suminf.    4.02619 (16) obj. 36297.5 iterations 2
# Cbc0038I Pass  16: suminf.    4.02619 (16) obj. 36297.5 iterations 4
# Cbc0038I Pass  17: suminf.    4.02619 (16) obj. 36297.5 iterations 8
# Cbc0038I Pass  18: suminf.    4.02619 (16) obj. 36297.5 iterations 7
# Cbc0038I Pass  19: suminf.    4.02619 (16) obj. 36297.5 iterations 5
# Cbc0038I Pass  20: suminf.    4.02619 (16) obj. 36297.5 iterations 22
# Cbc0038I Pass  21: suminf.    4.02619 (16) obj. 36297.5 iterations 26
# Cbc0038I Pass  22: suminf.    4.02619 (16) obj. 36297.5 iterations 7
# Cbc0038I Pass  23: suminf.    4.02619 (16) obj. 36297.5 iterations 1
# Cbc0038I Pass  24: suminf.    4.02619 (16) obj. 36297.5 iterations 2
# Cbc0038I Pass  25: suminf.    4.02619 (16) obj. 36297.5 iterations 1
# Cbc0038I Pass  26: suminf.    4.02619 (16) obj. 36297.5 iterations 5
# Cbc0038I Pass  27: suminf.    5.95632 (18) obj. 36297.5 iterations 83
# Cbc0038I Pass  28: suminf.    5.81959 (23) obj. 36297.5 iterations 37
# Cbc0038I Pass  29: suminf.    5.48912 (22) obj. 36297.5 iterations 5
# Cbc0038I Pass  30: suminf.    5.05464 (23) obj. 36297.5 iterations 7
# Cbc0038I Pass  31: suminf.    5.05464 (23) obj. 36297.5 iterations 21
# Cbc0038I Pass  32: suminf.    6.64994 (20) obj. 36297.5 iterations 58
# Cbc0038I Pass  33: suminf.    6.64994 (20) obj. 36297.5 iterations 5
# Cbc0038I Pass  34: suminf.    4.02619 (16) obj. 36297.5 iterations 53
# Cbc0038I Pass  35: suminf.    4.02619 (16) obj. 36297.5 iterations 7
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9815 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 269 rows 9900 columns, reduced to 35 rows 23 columns
# Cbc0038I Mini branch and bound improved solution from 36455 to 36408 (0.76 seconds)
# Cbc0038I Round again with cutoff of 36187.9
# Cbc0038I Reduced cost fixing fixed 9105 variables on major pass 5
# Cbc0038I Pass  35: suminf.   12.98682 (33) obj. 36187.9 iterations 0
# Cbc0038I Pass  36: suminf.    8.16897 (23) obj. 36187.9 iterations 37
# Cbc0038I Pass  37: suminf.    8.16897 (23) obj. 36187.9 iterations 5
# Cbc0038I Pass  38: suminf.   10.28147 (58) obj. 36187.9 iterations 68
# Cbc0038I Pass  39: suminf.    8.16897 (23) obj. 36187.9 iterations 104
# Cbc0038I Pass  40: suminf.    8.49625 (22) obj. 36187.9 iterations 111
# Cbc0038I Pass  41: suminf.    8.16897 (23) obj. 36187.9 iterations 43
# Cbc0038I Pass  42: suminf.    8.49625 (22) obj. 36187.9 iterations 56
# Cbc0038I Pass  43: suminf.    8.25814 (21) obj. 36187.9 iterations 46
# Cbc0038I Pass  44: suminf.    8.16897 (23) obj. 36187.9 iterations 11
# Cbc0038I Pass  45: suminf.    8.16897 (23) obj. 36187.9 iterations 26
# Cbc0038I Pass  46: suminf.   10.28147 (58) obj. 36187.9 iterations 54
# Cbc0038I Pass  47: suminf.    9.31084 (21) obj. 36187.9 iterations 24
# Cbc0038I Pass  48: suminf.    8.16897 (23) obj. 36187.9 iterations 41
# Cbc0038I Pass  49: suminf.    8.17191 (22) obj. 36187.9 iterations 69
# Cbc0038I Pass  50: suminf.    8.17191 (22) obj. 36187.9 iterations 49
# Cbc0038I Pass  51: suminf.    8.48768 (22) obj. 36187.9 iterations 42
# Cbc0038I Pass  52: suminf.    8.16897 (23) obj. 36187.9 iterations 27
# Cbc0038I Pass  53: suminf.    8.16897 (23) obj. 36187.9 iterations 33
# Cbc0038I Pass  54: suminf.    8.25814 (21) obj. 36187.9 iterations 22
# Cbc0038I Pass  55: suminf.    8.16897 (23) obj. 36187.9 iterations 20
# Cbc0038I Pass  56: suminf.    8.49625 (22) obj. 36187.9 iterations 118
# Cbc0038I Pass  57: suminf.    8.16897 (23) obj. 36187.9 iterations 28
# Cbc0038I Pass  58: suminf.    8.25814 (21) obj. 36187.9 iterations 36
# Cbc0038I Pass  59: suminf.    8.16897 (23) obj. 36187.9 iterations 45
# Cbc0038I Pass  60: suminf.    8.16897 (23) obj. 36187.9 iterations 23
# Cbc0038I Pass  61: suminf.   10.28147 (58) obj. 36187.9 iterations 44
# Cbc0038I Pass  62: suminf.    8.25814 (21) obj. 36187.9 iterations 40
# Cbc0038I Pass  63: suminf.    8.16897 (23) obj. 36187.9 iterations 19
# Cbc0038I Pass  64: suminf.   10.28147 (58) obj. 36187.9 iterations 73
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9812 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 269 rows 9900 columns, reduced to 44 rows 32 columns
# Cbc0038I Mini branch and bound did not improve solution (0.90 seconds)
# Cbc0038I After 0.90 seconds - Feasibility pump exiting with objective of 36408 - took 0.37 seconds
# Cbc0012I Integer solution of 36408 found by feasibility pump after 0 iterations and 0 nodes (0.90 seconds)
# Cbc0038I Full problem 269 rows 9900 columns, reduced to 103 rows 326 columns
# Cbc0012I Integer solution of 36241 found by greedy equality after 0 iterations and 0 nodes (0.98 seconds)
# Cbc0038I Full problem 269 rows 9900 columns, reduced to 36 rows 26 columns
# Cbc0031I 21 added rows had average density of 21.952381
# Cbc0013I At root node, 21 cuts changed objective from 35932.167 to 36147.363 in 7 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 4.0 elements, 45 column cuts (45 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 13 row cuts average 98.0 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 15 row cuts average 8.7 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 36241 best solution, best possible 36164.611 (1.15 seconds)
# Cbc0016I Integer solution of 36215 found by strong branching after 163 iterations and 2 nodes (1.17 seconds)
# Cbc0001I Search completed - best objective 36215, took 163 iterations and 2 nodes (1.17 seconds)
# Cbc0032I Strong branching done 158 times (1671 iterations), fathomed 1 nodes and fixed 4 variables
# Cbc0035I Maximum depth 0, 9670 variables fixed on reduced cost
# Total time (CPU seconds):       0.92   (Wallclock seconds):       1.19
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Clp0006I 0  Obj 35932.167
# Clp0000I Optimal - objective value 35932.167
#
# Starting MIP optimization
# Cgl0004I processed model has 273 rows, 9900 columns (9900 integer (9900 of which binary)) and 32374 elements
# Coin3009W Conflict graph built in 0.047 seconds, density: 0.500%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Fixing only non-zero variables.
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0045I Nauty did not find any useful orbits in time 0.116099
# Cbc0038I Initial state - 79 integers unsatisfied sum - 29.3333
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 56579 iterations 455
# Cbc0038I Solution found of 56579
# Cbc0038I Before mini branch and bound, 9808 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 273 rows 9900 columns, reduced to 52 rows 43 columns
# Cbc0038I Mini branch and bound improved solution from 56579 to 45553 (0.51 seconds)
# Cbc0038I Round again with cutoff of 44590
# Cbc0038I Pass   2: suminf.    1.34101 (10) obj. 44590 iterations 134
# Cbc0038I Solution found of 44098
# Cbc0038I Before mini branch and bound, 9805 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 273 rows 9900 columns, reduced to 46 rows 39 columns
# Cbc0038I Mini branch and bound improved solution from 44098 to 38729 (0.58 seconds)
# Cbc0038I Round again with cutoff of 38168.8
# Cbc0038I Reduced cost fixing fixed 2204 variables on major pass 3
# Cbc0038I Pass   3: suminf.    3.89723 (11) obj. 38168.8 iterations 209
# Cbc0038I Pass   4: suminf.    0.80757 (4) obj. 38168.8 iterations 185
# Cbc0038I Pass   5: suminf.    0.80757 (4) obj. 38168.8 iterations 46
# Cbc0038I Solution found of 37255
# Cbc0038I Before mini branch and bound, 9806 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 273 rows 9900 columns, reduced to 43 rows 34 columns
# Cbc0038I Mini branch and bound improved solution from 37255 to 36455 (0.68 seconds)
# Cbc0038I Round again with cutoff of 36297.5
# Cbc0038I Reduced cost fixing fixed 8820 variables on major pass 4
# Cbc0038I Pass   6: suminf.    9.75745 (33) obj. 36297.5 iterations 250
# Cbc0038I Pass   7: suminf.    9.75745 (33) obj. 36297.5 iterations 36
# Cbc0038I Pass   8: suminf.    9.75745 (33) obj. 36297.5 iterations 0
# Cbc0038I Pass   9: suminf.    3.97828 (8) obj. 36297.5 iterations 65
# Cbc0038I Pass  10: suminf.    3.97828 (8) obj. 36297.5 iterations 25
# Cbc0038I Pass  11: suminf.    4.00000 (11) obj. 36297.5 iterations 130
# Cbc0038I Pass  12: suminf.    3.96009 (9) obj. 36297.5 iterations 74
# Cbc0038I Pass  13: suminf.    3.96009 (9) obj. 36297.5 iterations 60
# Cbc0038I Pass  14: suminf.    3.98157 (9) obj. 36297.5 iterations 96
# Cbc0038I Pass  15: suminf.    3.98157 (9) obj. 36297.5 iterations 37
# Cbc0038I Pass  16: suminf.    3.96009 (9) obj. 36297.5 iterations 62
# Cbc0038I Pass  17: suminf.    3.97878 (9) obj. 36297.5 iterations 56
# Cbc0038I Pass  18: suminf.    3.97878 (9) obj. 36297.5 iterations 71
# Cbc0038I Pass  19: suminf.    3.98058 (9) obj. 36297.5 iterations 59
# Cbc0038I Pass  20: suminf.    3.98058 (9) obj. 36297.5 iterations 38
# Cbc0038I Pass  21: suminf.    3.97878 (9) obj. 36297.5 iterations 61
# Cbc0038I Pass  22: suminf.    3.97828 (8) obj. 36297.5 iterations 38
# Cbc0038I Pass  23: suminf.    3.97828 (8) obj. 36297.5 iterations 45
# Cbc0038I Pass  24: suminf.    4.00000 (11) obj. 36297.5 iterations 109
# Cbc0038I Pass  25: suminf.    3.99241 (11) obj. 36297.5 iterations 61
# Cbc0038I Pass  26: suminf.    3.97828 (8) obj. 36297.5 iterations 45
# Cbc0038I Pass  27: suminf.    3.96009 (9) obj. 36297.5 iterations 94
# Cbc0038I Pass  28: suminf.    3.96009 (9) obj. 36297.5 iterations 61
# Cbc0038I Pass  29: suminf.    3.98157 (9) obj. 36297.5 iterations 92
# Cbc0038I Pass  30: suminf.    3.98157 (9) obj. 36297.5 iterations 33
# Cbc0038I Pass  31: suminf.    3.96009 (9) obj. 36297.5 iterations 46
# Cbc0038I Pass  32: suminf.    3.98157 (9) obj. 36297.5 iterations 57
# Cbc0038I Pass  33: suminf.    3.96009 (9) obj. 36297.5 iterations 106
# Cbc0038I Pass  34: suminf.    3.98058 (9) obj. 36297.5 iterations 75
# Cbc0038I Pass  35: suminf.    3.98058 (9) obj. 36297.5 iterations 57
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9810 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 273 rows 9900 columns, reduced to 41 rows 29 columns
# Cbc0038I Mini branch and bound improved solution from 36455 to 36405 (0.85 seconds)
# Cbc0038I Round again with cutoff of 36187.9
# Cbc0038I Reduced cost fixing fixed 9105 variables on major pass 5
# Cbc0038I Pass  35: suminf.   12.98682 (33) obj. 36187.9 iterations 0
# Cbc0038I Pass  36: suminf.   12.05859 (31) obj. 36187.9 iterations 56
# Cbc0038I Pass  37: suminf.   10.79309 (59) obj. 36187.9 iterations 11
# Cbc0038I Pass  38: suminf.   10.79309 (59) obj. 36187.9 iterations 2
# Cbc0038I Pass  39: suminf.   10.79309 (59) obj. 36187.9 iterations 2
# Cbc0038I Pass  40: suminf.   10.79309 (59) obj. 36187.9 iterations 20
# Cbc0038I Pass  41: suminf.   10.79309 (59) obj. 36187.9 iterations 17
# Cbc0038I Pass  42: suminf.   10.79309 (59) obj. 36187.9 iterations 10
# Cbc0038I Pass  43: suminf.   10.79309 (59) obj. 36187.9 iterations 7
# Cbc0038I Pass  44: suminf.   10.79309 (59) obj. 36187.9 iterations 9
# Cbc0038I Pass  45: suminf.   10.79309 (59) obj. 36187.9 iterations 14
# Cbc0038I Pass  46: suminf.   10.79309 (59) obj. 36187.9 iterations 13
# Cbc0038I Pass  47: suminf.   10.79309 (59) obj. 36187.9 iterations 19
# Cbc0038I Pass  48: suminf.   10.79309 (59) obj. 36187.9 iterations 13
# Cbc0038I Pass  49: suminf.   10.79309 (59) obj. 36187.9 iterations 3
# Cbc0038I Pass  50: suminf.   10.79309 (59) obj. 36187.9 iterations 1
# Cbc0038I Pass  51: suminf.   10.79309 (59) obj. 36187.9 iterations 14
# Cbc0038I Pass  52: suminf.   11.36818 (59) obj. 36187.9 iterations 15
# Cbc0038I Pass  53: suminf.   11.36818 (59) obj. 36187.9 iterations 12
# Cbc0038I Pass  54: suminf.   10.79309 (59) obj. 36187.9 iterations 5
# Cbc0038I Pass  55: suminf.    9.64429 (59) obj. 36187.9 iterations 10
# Cbc0038I Pass  56: suminf.    9.64429 (59) obj. 36187.9 iterations 11
# Cbc0038I Pass  57: suminf.    9.64429 (59) obj. 36187.9 iterations 0
# Cbc0038I Pass  58: suminf.   12.86747 (33) obj. 36187.9 iterations 25
# Cbc0038I Pass  59: suminf.   10.24470 (59) obj. 36187.9 iterations 25
# Cbc0038I Pass  60: suminf.    9.64429 (59) obj. 36187.9 iterations 2
# Cbc0038I Pass  61: suminf.    9.64429 (59) obj. 36187.9 iterations 2
# Cbc0038I Pass  62: suminf.    9.64429 (59) obj. 36187.9 iterations 2
# Cbc0038I Pass  63: suminf.    9.64429 (59) obj. 36187.9 iterations 1
# Cbc0038I Pass  64: suminf.   13.64602 (33) obj. 36187.9 iterations 26
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9812 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 273 rows 9900 columns, reduced to 39 rows 28 columns
# Cbc0038I Mini branch and bound did not improve solution (0.97 seconds)
# Cbc0038I After 0.97 seconds - Feasibility pump exiting with objective of 36405 - took 0.37 seconds
# Cbc0012I Integer solution of 36405 found by feasibility pump after 0 iterations and 0 nodes (0.97 seconds)
# Cbc0038I Full problem 273 rows 9900 columns, reduced to 105 rows 323 columns
# Cbc0012I Integer solution of 36241 found by greedy equality after 0 iterations and 0 nodes (1.06 seconds)
# Cbc0038I Full problem 273 rows 9900 columns, reduced to 37 rows 26 columns
# Cbc0031I 27 added rows had average density of 15.185185
# Cbc0013I At root node, 27 cuts changed objective from 35932.167 to 36215.8 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 29 row cuts average 7.6 elements, 53 column cuts (53 active)  in 0.011 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 10 row cuts average 108.8 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 26 row cuts average 6.9 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0016I Integer solution of 36230 found by strong branching after 152 iterations and 0 nodes (1.20 seconds)
# Cbc0001I Search completed - best objective 36230, took 153 iterations and 0 nodes (1.20 seconds)
# Cbc0032I Strong branching done 16 times (179 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 9553 variables fixed on reduced cost
# Total time (CPU seconds):       0.96   (Wallclock seconds):       1.22
#
# Solution value  =  36230.0
